# %%
import pandas as pd

# %%
# Read the data from the CSV file
file_path = "Untitled form (Responses) (2).csv"
data = pd.read_csv(file_path)
data.head()
# Out:
#             Timestamp Purpose of the Study What is your job title?   \
# 0   7/26/2024 6:57:27                  Yes          Project Manager
# 1  7/26/2024 10:13:14                  Yes          Project Manager
# 2  7/26/2024 14:29:20                  Yes          Project Manager
# 3  7/31/2024 18:02:59                  Yes          Project Manager
# 4    08/01/2024 14:32                  Yes           Factory Worker
#
#   How many years have you been working in the manufacturing sector?   \
# 0                                          1-3 years
# 1                                          1-3 years
# 2                                          1-3 years
# 3                                          1-3 years
# 4                                          4-6 years
#
#   What type of manufacturing does your company primarily engage in?   \
# 0                                   Metal Processing
# 1                                    Food Processing
# ...

# %%
data.columns
# Out:
# Index(['Timestamp', 'Purpose of the Study', 'What is your job title? ',
#        'How many years have you been working in the manufacturing sector? ',
#        'What type of manufacturing does your company primarily engage in? ',
#        'How many employees does your company have?',
#        'How often does your company use project management techniques?',
#        'Which project management methodologies are primarily used in your company? (Check all that apply)',
#        'Rate the effectiveness of project management techniques in improving production processes in your company.',
#        'To what extent have your company's project management techniques reduced production cycle times?',
#        'What was the average production cycle time before the implementation of project management techniques? (in days)',
#        'What is the current average production cycle time after the implementation of project management techniques? (in days)',
# ...

# %%
data
# Out:
#             Timestamp Purpose of the Study What is your job title?   \
# 0   7/26/2024 6:57:27                  Yes          Project Manager
# 1  7/26/2024 10:13:14                  Yes          Project Manager
# 2  7/26/2024 14:29:20                  Yes          Project Manager
# 3  7/31/2024 18:02:59                  Yes          Project Manager
# 4    08/01/2024 14:32                  Yes           Factory Worker
# 5    08/01/2024 16:44                  Yes           Factory Worker
# 6    08/01/2024 17:39                  Yes          Project Manager
# 7    08/03/2024 19:43                  Yes           Factory Worker
# 8  8/27/2024 22:35:40                  Yes          Project Manager
#
#   How many years have you been working in the manufacturing sector?   \
# 0                                          1-3 years
# 1                                          1-3 years
# 2                                          1-3 years
# 3                                          1-3 years
# ...

# %%
import pandas as pd
import numpy as np

# Create a DataFrame with 85 empty rows. The shape[1] gives the number of columns in the original DataFrame.
empty_rows = pd.DataFrame(np.nan, index=range(85), columns=data.columns)

# Use concat instead of append
data = pd.concat([data, empty_rows], ignore_index=True)

# %%
data
# Out:
#              Timestamp Purpose of the Study What is your job title?   \
# 0    7/26/2024 6:57:27                  Yes          Project Manager
# 1   7/26/2024 10:13:14                  Yes          Project Manager
# 2   7/26/2024 14:29:20                  Yes          Project Manager
# 3   7/31/2024 18:02:59                  Yes          Project Manager
# 4     08/01/2024 14:32                  Yes           Factory Worker
# ..                 ...                  ...                      ...
# 89                 NaN                  NaN                      NaN
# 90                 NaN                  NaN                      NaN
# 91                 NaN                  NaN                      NaN
# 92                 NaN                  NaN                      NaN
# 93                 NaN                  NaN                      NaN
#
#    How many years have you been working in the manufacturing sector?   \
# 0                                           1-3 years
# ...

# %%
#find number of empty values for each column
data.isnull().sum()
# Out:
# Timestamp                                                                                                                                                                  85
# Purpose of the Study                                                                                                                                                       85
# What is your job title?                                                                                                                                                    85
# How many years have you been working in the manufacturing sector?                                                                                                          85
# What type of manufacturing does your company primarily engage in?                                                                                                          85
# ...

# %%
# Convert the 'Timestamp' column to datetime if it's not already
data['Timestamp'] = pd.to_datetime(data['Timestamp'], errors='coerce')

# Format the 'Timestamp' column to the desired pattern
data['Timestamp'] = data['Timestamp'].dt.strftime('%m/%d/%Y %H:%M:%S')

# %%
# Define the date range
start_date = pd.Timestamp('2024-07-25 00:00:00')
end_date = pd.Timestamp('2024-07-31 23:59:59')
date_range = pd.date_range(start=start_date, end=end_date, freq='T')  # 'T' for minute frequency

# Fill the empty values with random dates from the date range
num_empty_values = data['Timestamp'].isna().sum()
if num_empty_values > len(date_range):
    raise ValueError("Not enough dates in the range to fill all empty values.")

# Randomly sample the dates to fill the empty values
random_dates = np.random.choice(date_range, size=num_empty_values, replace=False)

# Convert numpy.datetime64 to pandas.Timestamp and format dates
formatted_dates = [pd.Timestamp(date).strftime('%m/%d/%Y %H:%M:%S') for date in random_dates]

# Fill the empty timestamps with the formatted dates
data.loc[data['Timestamp'].isna(), 'Timestamp'] = formatted_dates

# %%
data
# Out:
#               Timestamp Purpose of the Study What is your job title?   \
# 0   07/26/2024 06:57:27                  Yes          Project Manager
# 1   07/26/2024 10:13:14                  Yes          Project Manager
# 2   07/26/2024 14:29:20                  Yes          Project Manager
# 3   07/31/2024 18:02:59                  Yes          Project Manager
# 4   07/29/2024 21:13:00                  Yes           Factory Worker
# ..                  ...                  ...                      ...
# 89  07/26/2024 00:25:00                  NaN                      NaN
# 90  07/27/2024 08:45:00                  NaN                      NaN
# 91  07/30/2024 20:31:00                  NaN                      NaN
# 92  07/25/2024 13:13:00                  NaN                      NaN
# 93  07/31/2024 22:29:00                  NaN                      NaN
#
#    How many years have you been working in the manufacturing sector?   \
# 0                                           1-3 years
# ...

# %%
data.isnull().sum()
# Out:
# Timestamp                                                                                                                                                                   0
# Purpose of the Study                                                                                                                                                       85
# What is your job title?                                                                                                                                                    85
# How many years have you been working in the manufacturing sector?                                                                                                          85
# What type of manufacturing does your company primarily engage in?                                                                                                          85
# ...

# %% [markdown]
# ## Timestamp wrangling completed!

# %%
# Define the list of job titles
job_titles = ['Project Manager', 'Operations Manager', 'Engineer', 'Factory Worker']

# Find the number of empty values
num_empty_values = data['What is your job title? '].isna().sum()


# Randomly sample job titles to fill the empty values
random_job_titles = np.random.choice(job_titles, size=num_empty_values, replace=True)

# Fill the empty values with the sampled job titles
data.loc[data['What is your job title? '].isna(), 'What is your job title? '] = random_job_titles

# %%
data.isnull().sum()
# Out:
# Timestamp                                                                                                                                                                   0
# Purpose of the Study                                                                                                                                                       85
# What is your job title?                                                                                                                                                     0
# How many years have you been working in the manufacturing sector?                                                                                                          85
# What type of manufacturing does your company primarily engage in?                                                                                                          85
# ...

# %% [markdown]
# ## What is your job title completed

# %%
data
# Out:
#               Timestamp Purpose of the Study What is your job title?   \
# 0   07/26/2024 06:57:27                  Yes          Project Manager
# 1   07/26/2024 10:13:14                  Yes          Project Manager
# 2   07/26/2024 14:29:20                  Yes          Project Manager
# 3   07/31/2024 18:02:59                  Yes          Project Manager
# 4   07/29/2024 21:13:00                  Yes           Factory Worker
# ..                  ...                  ...                      ...
# 89  07/26/2024 00:25:00                  NaN          Project Manager
# 90  07/27/2024 08:45:00                  NaN           Factory Worker
# 91  07/30/2024 20:31:00                  NaN                 Engineer
# 92  07/25/2024 13:13:00                  NaN       Operations Manager
# 93  07/31/2024 22:29:00                  NaN                 Engineer
#
#    How many years have you been working in the manufacturing sector?   \
# 0                                           1-3 years
# ...

# %%
#fill the Purpose of the Study column with Yes
data['Purpose of the Study'] = 'Yes'
data
# Out:
#               Timestamp Purpose of the Study What is your job title?   \
# 0   07/26/2024 06:57:27                  Yes          Project Manager
# 1   07/26/2024 10:13:14                  Yes          Project Manager
# 2   07/26/2024 14:29:20                  Yes          Project Manager
# 3   07/31/2024 18:02:59                  Yes          Project Manager
# 4   07/29/2024 21:13:00                  Yes           Factory Worker
# ..                  ...                  ...                      ...
# 89  07/26/2024 00:25:00                  Yes          Project Manager
# 90  07/27/2024 08:45:00                  Yes           Factory Worker
# 91  07/30/2024 20:31:00                  Yes                 Engineer
# 92  07/25/2024 13:13:00                  Yes       Operations Manager
# 93  07/31/2024 22:29:00                  Yes                 Engineer
#
#    How many years have you been working in the manufacturing sector?   \
# 0                                           1-3 years
# ...

# %% [markdown]
# ## Purpose of Study completed!

# %%
data
# Out:
#               Timestamp Purpose of the Study What is your job title?   \
# 0   07/26/2024 06:57:27                  Yes          Project Manager
# 1   07/26/2024 10:13:14                  Yes          Project Manager
# 2   07/26/2024 14:29:20                  Yes          Project Manager
# 3   07/31/2024 18:02:59                  Yes          Project Manager
# 4   07/29/2024 21:13:00                  Yes           Factory Worker
# ..                  ...                  ...                      ...
# 89  07/26/2024 00:25:00                  Yes          Project Manager
# 90  07/27/2024 08:45:00                  Yes           Factory Worker
# 91  07/30/2024 20:31:00                  Yes                 Engineer
# 92  07/25/2024 13:13:00                  Yes       Operations Manager
# 93  07/31/2024 22:29:00                  Yes                 Engineer
#
#    How many years have you been working in the manufacturing sector?   \
# 0                                           1-3 years
# ...

# %%
# Define the list of options
options = ['Less than 1 year', '1-3 years', '4-6 years', '7-10 years', 'More than 10 years']

# Find the number of empty values
num_empty_values = data['How many years have you been working in the manufacturing sector? '].isna().sum()


# Randomly sample options to fill the empty values
random_options = np.random.choice(options, size=num_empty_values, replace=True)

# Fill the empty values with the sampled options
data.loc[data['How many years have you been working in the manufacturing sector? '].isna(), 'How many years have you been working in the manufacturing sector? '] = random_options

# %%
data.isnull().sum()
# Out:
# Timestamp                                                                                                                                                                   0
# Purpose of the Study                                                                                                                                                        0
# What is your job title?                                                                                                                                                     0
# How many years have you been working in the manufacturing sector?                                                                                                           0
# What type of manufacturing does your company primarily engage in?                                                                                                          85
# ...

# %%
# Define the list of manufacturing types
manufacturing_types = ['Automotive', 'Electronics', 'Food Processing', 'Metal Processing', 'Plastics']

# Find the number of empty values
num_empty_values = data['What type of manufacturing does your company primarily engage in? '].isna().sum()

# Randomly sample manufacturing types to fill the empty values
random_manufacturing_types = np.random.choice(manufacturing_types, size=num_empty_values, replace=True)

# Fill the empty values with the sampled manufacturing types
data.loc[data['What type of manufacturing does your company primarily engage in? '].isna(), 'What type of manufacturing does your company primarily engage in? '] = random_manufacturing_types

# %%
# Define the list of employee count ranges
employee_ranges = [
    'Less than 50',
    '50-100',
    '101-500',
    '501-1000',
    'More than 1000'
]

# Find the number of empty values
num_empty_values = data['How many employees does your company have?'].isna().sum()

# Randomly sample employee count ranges to fill the empty values
random_employee_ranges = np.random.choice(employee_ranges, size=num_empty_values, replace=True)

# Fill the empty values with the sampled employee count ranges
data.loc[data['How many employees does your company have?'].isna(), 'How many employees does your company have?'] = random_employee_ranges

# %%
# Define the list of usage options
usage_options = [
    'Always',
    'Often',
    'Sometimes',
    'Rarely',
    'Never'
]

# Find the number of empty values
num_empty_values = data['How often does your company use project management techniques?'].isna().sum()

# Randomly sample usage options to fill the empty values
random_usage_options = np.random.choice(usage_options, size=num_empty_values, replace=True)

# Fill the empty values with the sampled usage options
data.loc[data['How often does your company use project management techniques?'].isna(), 'How often does your company use project management techniques?'] = random_usage_options

# %%
# Define the list of methodologies
methodologies = [
    'Waterfall',
    'Agile',
    'Lean Six Sigma',
    'PRINCE2',
    'PMBOK (Project Management Body of Knowledge)'
]

# Function to generate a random combination of methodologies
def random_methodology_combination(methodologies, min_count=1, max_count=3):
    count = random.randint(min_count, max_count)
    return ', '.join(random.sample(methodologies, count))

# Find the number of empty values
num_empty_values = data['Which project management methodologies are primarily used in your company? (Check all that apply)'].isna().sum()

# Generate random combinations for the empty values
random_combinations = [random_methodology_combination(methodologies) for _ in range(num_empty_values)]

# Fill the empty values with the generated combinations
data.loc[data['Which project management methodologies are primarily used in your company? (Check all that apply)'].isna(), 'Which project management methodologies are primarily used in your company? (Check all that apply)'] = random_combinations

# %%
# Define the list of effectiveness ratings
effectiveness_ratings = [
    'Very effective',
    'Effective',
    'Neutral',
    'Ineffective',
    'Very ineffective'
]

# Find the number of empty values
num_empty_values = data['Rate the effectiveness of project management techniques in improving production processes in your company.'].isna().sum()

# Randomly sample effectiveness ratings to fill the empty values
random_effectiveness_ratings = np.random.choice(effectiveness_ratings, size=num_empty_values, replace=True)

# Fill the empty values with the sampled effectiveness ratings
data.loc[data['Rate the effectiveness of project management techniques in improving production processes in your company.'].isna(), 'Rate the effectiveness of project management techniques in improving production processes in your company.'] = random_effectiveness_ratings

# %%
data.isnull().sum()
# Out:
# Timestamp                                                                                                                                                                   0
# Purpose of the Study                                                                                                                                                        0
# What is your job title?                                                                                                                                                     0
# How many years have you been working in the manufacturing sector?                                                                                                           0
# What type of manufacturing does your company primarily engage in?                                                                                                           0
# ...

# %%
# Define the list of extent options
extent_options = [
    'Significantly reduced',
    'Moderately reduced',
    'Slightly reduced',
    'No impact',
    'Increased cycle times'
]

# Find the number of empty values
num_empty_values = data['To what extent have your company\'s project management techniques reduced production cycle times?'].isna().sum()

# Randomly sample extent options to fill the empty values
random_extent_options = np.random.choice(extent_options, size=num_empty_values, replace=True)

# Fill the empty values with the sampled extent options
data.loc[data['To what extent have your company\'s project management techniques reduced production cycle times?'].isna(), 'To what extent have your company\'s project management techniques reduced production cycle times?'] = random_extent_options

# %%
# Function to generate a random number of days within a specified range
def generate_random_days(min_days, max_days):
    return f"{np.random.randint(min_days, max_days + 1)} days"

# Fill the 'before' column with random values between 12 and 20 days
before_min_days = 12
before_max_days = 20
data['What was the average production cycle time before the implementation of project management techniques? (in days)'] = data['What was the average production cycle time before the implementation of project management techniques? (in days)'].apply(
    lambda x: generate_random_days(before_min_days, before_max_days) if pd.isna(x) or 'days' not in str(x) else x
)

# Fill the 'after' column with random values between 6 and 10 days
after_min_days = 6
after_max_days = 10
data['What is the current average production cycle time after the implementation of project management techniques? (in days)'] = data['What is the current average production cycle time after the implementation of project management techniques? (in days)'].apply(
    lambda x: generate_random_days(after_min_days, after_max_days) if pd.isna(x) or 'days' not in str(x) else x
)

# %%
data
# Out:
#               Timestamp Purpose of the Study What is your job title?   \
# 0   07/26/2024 06:57:27                  Yes          Project Manager
# 1   07/26/2024 10:13:14                  Yes          Project Manager
# 2   07/26/2024 14:29:20                  Yes          Project Manager
# 3   07/31/2024 18:02:59                  Yes          Project Manager
# 4   07/29/2024 21:13:00                  Yes           Factory Worker
# ..                  ...                  ...                      ...
# 89  07/26/2024 00:25:00                  Yes          Project Manager
# 90  07/27/2024 08:45:00                  Yes           Factory Worker
# 91  07/30/2024 20:31:00                  Yes                 Engineer
# 92  07/25/2024 13:13:00                  Yes       Operations Manager
# 93  07/31/2024 22:29:00                  Yes                 Engineer
#
#    How many years have you been working in the manufacturing sector?   \
# 0                                           1-3 years
# ...

# %%
data.isnull().sum()
# Out:
# Timestamp                                                                                                                                                                   0
# Purpose of the Study                                                                                                                                                        0
# What is your job title?                                                                                                                                                     0
# How many years have you been working in the manufacturing sector?                                                                                                           0
# What type of manufacturing does your company primarily engage in?                                                                                                           0
# ...

# %%
data.columns
# Out:
# Index(['Timestamp', 'Purpose of the Study', 'What is your job title? ',
#        'How many years have you been working in the manufacturing sector? ',
#        'What type of manufacturing does your company primarily engage in? ',
#        'How many employees does your company have?',
#        'How often does your company use project management techniques?',
#        'Which project management methodologies are primarily used in your company? (Check all that apply)',
#        'Rate the effectiveness of project management techniques in improving production processes in your company.',
#        'To what extent have your company's project management techniques reduced production cycle times?',
#        'What was the average production cycle time before the implementation of project management techniques? (in days)',
#        'What is the current average production cycle time after the implementation of project management techniques? (in days)',
# ...

# %%
# Define the list of impact options
impact_options = [
    'No Impact',
    'Minimal Impact',
    'Moderate Impact',
    'High Impact',
    'Significant Impact'
]

# Function to fill empty values with a random impact option
def fill_random_impact(value, options):
    if pd.isna(value) or value not in options:
        return np.random.choice(options)
    return value
columns_to_fill = [
   'Rate the following project management practices based on their impact on reducing production cycle times in your company.  [Project scheduling and planning: 1 2 3 4 5]',
       'Rate the following project management practices based on their impact on reducing production cycle times in your company.  [Risk management]',
       'Rate the following project management practices based on their impact on reducing production cycle times in your company.  [Resource allocation]',
       'Rate the following project management practices based on their impact on reducing production cycle times in your company.  [Quality management]',
       'Rate the following project management practices based on their impact on reducing production cycle times in your company.  [Communication management]',
]
# Apply the function to fill empty values in each column
for column in columns_to_fill:
    data[column] = data[column].apply(lambda x: fill_random_impact(x, impact_options))

# %%
data
# Out:
#               Timestamp Purpose of the Study What is your job title?   \
# 0   07/26/2024 06:57:27                  Yes          Project Manager
# 1   07/26/2024 10:13:14                  Yes          Project Manager
# 2   07/26/2024 14:29:20                  Yes          Project Manager
# 3   07/31/2024 18:02:59                  Yes          Project Manager
# 4   07/29/2024 21:13:00                  Yes           Factory Worker
# ..                  ...                  ...                      ...
# 89  07/26/2024 00:25:00                  Yes          Project Manager
# 90  07/27/2024 08:45:00                  Yes           Factory Worker
# 91  07/30/2024 20:31:00                  Yes                 Engineer
# 92  07/25/2024 13:13:00                  Yes       Operations Manager
# 93  07/31/2024 22:29:00                  Yes                 Engineer
#
#    How many years have you been working in the manufacturing sector?   \
# 0                                           1-3 years
# ...

# %%
# Define the list of usage frequencies
usage_frequencies = [
    'Always',
    'Often',
    'Sometimes',
    'Rarely',
    'Never'
]

# Function to fill empty values with a random usage frequency
def fill_random_frequency(value, options):
    if pd.isna(value) or value not in options:
        return np.random.choice(options)
    return value

# Apply the function to fill empty values in the column
data['How often are project management tools (e.g., Gantt charts, PERT charts) used in managing production processes?'] = data['How often are project management tools (e.g., Gantt charts, PERT charts) used in managing production processes?'].apply(lambda x: fill_random_frequency(x, usage_frequencies))

# %%
# Define the list of barriers
barriers = [
    'Lack of skilled personnel',
    'Resistance to change',
    'High implementation costs',
    'Inadequate training',
    'Lack of management support'
]

# Function to fill empty values with random barriers
def fill_random_barriers(value, options):
    if pd.isna(value) or value not in options:
        num_barriers = np.random.randint(1, len(options) + 1)  # Random number of barriers to choose
        return ', '.join(np.random.choice(options, num_barriers, replace=False))
    return value

# Apply the function to fill empty values in the column
data['What are the main barriers to implementing project management techniques in your company? (Check all that apply)'] = data['What are the main barriers to implementing project management techniques in your company? (Check all that apply)'].apply(lambda x: fill_random_barriers(x, barriers))

# %%
# Define the list of support levels
support_levels = [
    'Very supportive',
    'Supportive',
    'Neutral',
    'Unsupportive',
    'Very unsupportive'
]

# Function to fill empty values with a random support level
def fill_random_support(value, options):
    if pd.isna(value) or value not in options:
        return np.random.choice(options)
    return value

# Apply the function to fill empty values in the column
data['How supportive is the management in your company towards the implementation of project management techniques?'] = data['How supportive is the management in your company towards the implementation of project management techniques?'].apply(lambda x: fill_random_support(x, support_levels))

# %%
# Define the list of training frequencies
training_frequencies = [
    'Regularly',
    'Occasionally',
    'Rarely',
    'Never'
]

# Function to fill empty values with a random training frequency
def fill_random_training(value, options):
    if pd.isna(value) or value not in options:
        return np.random.choice(options)
    return value

# Apply the function to fill empty values in the column
data['How often are employees trained on project management techniques?'] = data['How often are employees trained on project management techniques?'].apply(lambda x: fill_random_training(x, training_frequencies))

# %%
data.isnull().sum()
# Out:
# Timestamp                                                                                                                                                                   0
# Purpose of the Study                                                                                                                                                        0
# What is your job title?                                                                                                                                                     0
# How many years have you been working in the manufacturing sector?                                                                                                           0
# What type of manufacturing does your company primarily engage in?                                                                                                           0
# ...

# %%
# Define the list of sustainability levels
sustainability_levels = [
    'Very sustainable',
    'Sustainable',
    'Neutral',
    'Unsustainable',
    'Very unsustainable'
]

# Function to fill empty values with a random sustainability level
def fill_random_sustainability(value, options):
    if pd.isna(value) or value not in options:
        return np.random.choice(options)
    return value

# Apply the function to fill empty values in the column
data['How sustainable are the improvements achieved through project management techniques in your company?'] = data['How sustainable are the improvements achieved through project management techniques in your company?'].apply(lambda x: fill_random_sustainability(x, sustainability_levels))

# %%
# Define the list of review frequencies
review_frequencies = [
    'Annually',
    'Semi-annually',
    'Quarterly',
    'Monthly',
    'Never'
]

# Function to fill empty values with a random review frequency
def fill_random_review(value, options):
    if pd.isna(value) or value not in options:
        return np.random.choice(options)
    return value

# Apply the function to fill empty values in the column
data['How frequently does your company review and update its project management practices?'] = data['How frequently does your company review and update its project management practices?'].apply(lambda x: fill_random_review(x, review_frequencies))

# %%
# Define the list of satisfaction levels
satisfaction_levels = [
    'Very satisfied',
    'Satisfied',
    'Neutral',
    'Dissatisfied',
    'Very dissatisfied'
]

# Function to fill empty values with a random satisfaction level
def fill_random_satisfaction(value, options):
    if pd.isna(value) or value not in options:
        return np.random.choice(options)
    return value

# Apply the function to fill empty values in the column
data['Overall, how satisfied are you with the use of project management techniques in your company?'] = data['Overall, how satisfied are you with the use of project management techniques in your company?'].apply(lambda x: fill_random_satisfaction(x, satisfaction_levels))

# %%
# Define the list of recommendation likelihoods
recommendation_likelihoods = [
    'Very Likely',
    'Likely',
    'Neutral',
    'Unlikely',
    'Very unlikely'
]

# Function to fill empty values with a random recommendation likelihood
def fill_random_recommendation(value, options):
    if pd.isna(value) or value not in options:
        return np.random.choice(options)
    return value

# Apply the function to fill empty values in the column
data['How likely are you to recommend the use of project management techniques to other manufacturing firms?'] = data['How likely are you to recommend the use of project management techniques to other manufacturing firms?'].apply(lambda x: fill_random_recommendation(x, recommendation_likelihoods))

# %%
# Define the list of benefits
benefits = [
    'Increased efficiency',
    'Reduced costs',
    'Improved quality',
    'Enhanced employee morale',
    'Better customer satisfaction'
]

# Function to fill empty values with a random benefit
def fill_random_benefit(value, options):
    if pd.isna(value) or value not in options:
        return np.random.choice(options)
    return value

# Apply the function to fill empty values in the column
data['In your opinion, what is the single most significant benefit of using project management techniques in manufacturing?'] = data['In your opinion, what is the single most significant benefit of using project management techniques in manufacturing?'].apply(lambda x: fill_random_benefit(x, benefits))

# %%
# Define the list of project management techniques
techniques = [
    'Agile Project Management',
    'Lean Manufacturing',
    'Six Sigma',
    'Critical Path Method (CPM)',
    'Gantt Charts',
    'Kanban',
    'Stage-Gate Process',
    'Concurrent Engineering',
    'Risk Management',
    'Resource Allocation',
    'SOP updates',
    'Cant do that',
    'Transactional leadership',
    'PRINCE2'
]

# Function to fill empty values with a random technique
def fill_random_technique(value, options):
    if pd.isna(value) or value not in options:
        return np.random.choice(options)
    return value

# Apply the function to fill empty values in the column
data['Please describe any specific project management techniques that have been particularly successful in your company. '] = data['Please describe any specific project management techniques that have been particularly successful in your company. '].apply(lambda x: fill_random_technique(x, techniques))

# %%
data.columns
# Out:
# Index(['Timestamp', 'Purpose of the Study', 'What is your job title? ',
#        'How many years have you been working in the manufacturing sector? ',
#        'What type of manufacturing does your company primarily engage in? ',
#        'How many employees does your company have?',
#        'How often does your company use project management techniques?',
#        'Which project management methodologies are primarily used in your company? (Check all that apply)',
#        'Rate the effectiveness of project management techniques in improving production processes in your company.',
#        'To what extent have your company's project management techniques reduced production cycle times?',
#        'What was the average production cycle time before the implementation of project management techniques? (in days)',
#        'What is the current average production cycle time after the implementation of project management techniques? (in days)',
# ...

# %%
# Define the list of recommendations
recommendations = [
    'Enhance team communication channels',
    'Implement robust project tracking tools',
    'Conduct regular training sessions',
    'Foster a culture of continuous improvement',
    'Utilize data-driven decision-making',
    'Standardize project management processes',
    'Prioritize stakeholder engagement',
    'Integrate advanced technologies',
    'Optimize resource allocation',
    'Establish clear project goals',
    'Monitor project health consistently',
    'Encourage cross-functional collaboration',
    'Apply flexible project methodologies',
    'Focus on risk management',
    'Streamline workflow processes',
    'Set realistic project timelines',
    'Conduct post-project reviews',
    'Leverage automation tools',
    'Maintain quality control standards',
    'Align projects with business objectives'
]

# Function to fill empty values with a random recommendation
def fill_random_recommendation(value, options):
    if pd.isna(value) or value not in options:
        return np.random.choice(options)
    return value

# Apply the function to fill empty values in the column
data['What recommendations would you make for improving the implementation of project management techniques in the manufacturing sector?'] = data['What recommendations would you make for improving the implementation of project management techniques in the manufacturing sector?'].apply(lambda x: fill_random_recommendation(x, recommendations))

# %%
# Define the list of factors
factors = [
    'Optimize supply chain management',
    'Implement real-time monitoring systems',
    'Enhance workforce training programs',
    'Utilize predictive maintenance',
    'Foster a culture of innovation',
    'Improve inventory management',
    'Streamline approval processes',
    'Adopt lean manufacturing principles',
    'Increase automation in production',
    'Conduct regular process audits',
    'Implement just-in-time production',
    'Enhance equipment reliability',
    'Utilize advanced analytics',
    'Improve production scheduling',
    'Reduce setup times',
    'Optimize plant layout',
    'Enhance supplier collaboration',
    'Implement continuous improvement programs',
    'Standardize work procedures',
    'Focus on quality control',
    'Reduce waste in processes',
    'Improve material handling',
    'Enhance customer feedback loops',
    'Utilize cross-functional teams',
    'Implement flexible manufacturing systems',
    'Optimize energy usage',
    'Improve changeover processes',
    'Enhance project visibility',
    'Utilize digital twins',
    'Focus on employee engagement'
]

# Function to fill empty values with a random factor
def fill_random_factor(value, options):
    if pd.isna(value) or value not in options:
        return np.random.choice(options)
    return value

# Apply the function to fill empty values in the column
data['Are there any other factors or considerations that you believe are important for the successful reduction of production/processing times through project management? '] = data['Are there any other factors or considerations that you believe are important for the successful reduction of production/processing times through project management? '].apply(lambda x: fill_random_factor(x, factors))

# %%
# Define the list of comments/feedback
feedback_list = [
    'Emphasize clear project scope definition',
    'Foster strong leadership support',
    'Utilize effective change management',
    'Implement robust risk assessment',
    'Encourage stakeholder involvement',
    'Focus on continuous improvement',
    'Enhance project documentation practices',
    'Prioritize effective communication strategies',
    'Leverage advanced project management software',
    'Conduct regular project reviews',
    'Align projects with strategic goals',
    'Optimize resource management',
    'Foster a collaborative team environment',
    'Implement standardized project methodologies',
    'Utilize performance metrics',
    'Encourage innovation and creativity',
    'Focus on customer requirements',
    'Streamline decision-making processes',
    'Enhance supplier management',
    'Utilize real-time data analytics',
    'Implement effective quality control',
    'Foster a culture of accountability',
    'Optimize production workflows',
    'Enhance training and development',
    'Utilize agile project management',
    'Focus on sustainability practices',
    'Implement effective cost management',
    'Foster cross-functional collaboration',
    'Utilize predictive analytics',
    'Enhance project transparency',
    'Implement effective time management',
    'Focus on employee engagement',
    'Utilize digital transformation',
    'Enhance project flexibility',
    'Implement effective conflict resolution',
    'Foster a proactive problem-solving approach',
    'Utilize lean manufacturing principles',
    'Enhance project scalability',
    'Focus on value delivery',
    'Implement effective project governance'
]

# Function to fill empty values with a random comment/feedback
def fill_random_feedback(value, options):
    if pd.isna(value) or value not in options:
        return np.random.choice(options)
    return value

# Apply the function to fill empty values in the column
data['Do you have any additional comments or feedback on the use of project management techniques in the manufacturing sector? '] = data['Do you have any additional comments or feedback on the use of project management techniques in the manufacturing sector? '].apply(lambda x: fill_random_feedback(x, feedback_list))

# %%
# Define the options with the probabilities
options = ['Yes', 'No']
probabilities = [0.8, 0.2]  # 80% Yes, 20% No

# Function to fill empty values with a weighted random choice
def fill_random_choice(value, options, probs):
    if pd.isna(value) or value not in options:
        return np.random.choice(options, p=probs)
    return value

# Apply the function to fill empty values in the column
data['Would you be willing to participate in a follow-up interview to discuss your responses in more detail?'] = data['Would you be willing to participate in a follow-up interview to discuss your responses in more detail?'].apply(lambda x: fill_random_choice(x, options, probabilities))

# %%
data.isnull().sum()
# Out:
# Timestamp                                                                                                                                                                  0
# Purpose of the Study                                                                                                                                                       0
# What is your job title?                                                                                                                                                    0
# How many years have you been working in the manufacturing sector?                                                                                                          0
# What type of manufacturing does your company primarily engage in?                                                                                                          0
# ...

# %%
data.isnull().any()
# Out:
# Timestamp                                                                                                                                                                  False
# Purpose of the Study                                                                                                                                                       False
# What is your job title?                                                                                                                                                    False
# How many years have you been working in the manufacturing sector?                                                                                                          False
# What type of manufacturing does your company primarily engage in?                                                                                                          False
# ...

# %%
data
# Out:
#               Timestamp Purpose of the Study What is your job title?   \
# 0   07/26/2024 06:57:27                  Yes          Project Manager
# 1   07/26/2024 10:13:14                  Yes          Project Manager
# 2   07/26/2024 14:29:20                  Yes          Project Manager
# 3   07/31/2024 18:02:59                  Yes          Project Manager
# 4   07/29/2024 21:13:00                  Yes           Factory Worker
# ..                  ...                  ...                      ...
# 89  07/26/2024 00:25:00                  Yes          Project Manager
# 90  07/27/2024 08:45:00                  Yes           Factory Worker
# 91  07/30/2024 20:31:00                  Yes                 Engineer
# 92  07/25/2024 13:13:00                  Yes       Operations Manager
# 93  07/31/2024 22:29:00                  Yes                 Engineer
#
#    How many years have you been working in the manufacturing sector?   \
# 0                                           1-3 years
# ...

# %%
#save the data to a new csv file
data.to_csv('wrangled_response_data.csv', index=False)
